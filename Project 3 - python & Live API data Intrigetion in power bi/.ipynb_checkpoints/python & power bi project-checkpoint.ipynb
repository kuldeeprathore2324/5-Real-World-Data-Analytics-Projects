# %%
import numpy as ap
import pandas as pd
# !pip install requests
# Out:
# Requirement already satisfied: requests in c:\users\abdul\appdata\local\programs\python\python314\lib\site-packages (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\abdul\appdata\local\programs\python\python314\lib\site-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\abdul\appdata\local\programs\python\python314\lib\site-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\abdul\appdata\local\programs\python\python314\lib\site-packages (from requests) (2.6.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\abdul\appdata\local\programs\python\python314\lib\site-packages (from requests) (2026.1.4)

# %%
import requests

# %%
import requests

url = "https://api.worldbank.org/v2/country?per_page=300&format=json"

response = requests.get(url)

print(response.status_code)
print(response.headers["Content-Type"])
data = response.json()

print(data[1][:5])  # first 5 countries
# Out:
# 200
# application/json;charset=utf-8
# [{'id': 'ABW', 'iso2Code': 'AW', 'name': 'Aruba', 'region': {'id': 'LCN', 'iso2code': 'ZJ', 'value': 'Latin America & Caribbean '}, 'adminregion': {'id': '', 'iso2code': '', 'value': ''}, 'incomeLevel': {'id': 'HIC', 'iso2code': 'XD', 'value': 'High income'}, 'lendingType': {'id': 'LNX', 'iso2code': 'XX', 'value': 'Not classified'}, 'capitalCity': 'Oranjestad', 'longitude': '-70.0167', 'latitude': '12.5167'}, {'id': 'AFE', 'iso2Code': 'ZH', 'name': 'Africa Eastern and Southern', 'region': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'}, 'adminregion': {'id': '', 'iso2code': '', 'value': ''}, 'incomeLevel': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'}, 'lendingType': {'id': '', 'iso2code': '', 'value': 'Aggregates'}, 'capitalCity': '', 'longitude': '', 'latitude': ''}, {'id': 'AFG', 'iso2Code': 'AF', 'name': 'Afghanistan', 'region': {'id': 'MEA', 'iso2code': 'ZQ', 'value': 'Middle East, North Africa, Afghanistan & Pakistan'}, 'adminregion': {'id': 'MNA', 'iso2code': 'XQ', 'value': 'Middle East, North Africa, Afghanistan & Pakistan (excluding high income)'}, 'incomeLevel': {'id': 'LIC', 'iso2code': 'XM', 'value': 'Low income'}, 'lendingType': {'id': 'IDX', 'iso2code': 'XI', 'value': 'IDA'}, 'capitalCity': 'Kabul', 'longitude': '69.1761', 'latitude': '34.5228'}, {'id': 'AFR', 'iso2Code': 'A9', 'name': 'Africa', 'region': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'}, 'adminregion': {'id': '', 'iso2code': '', 'value': ''}, 'incomeLevel': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'}, 'lendingType': {'id': '', 'iso2code': '', 'value': 'Aggregates'}, 'capitalCity': '', 'longitude': '', 'latitude': ''}, {'id': 'AFW', 'iso2Code': 'ZI', 'name': 'Africa Western and Central', 'region': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'}, 'adminregion': {'id': '', 'iso2code': '', 'value': ''}, 'incomeLevel': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'}, 'lendingType': {'id': '', 'iso2code': '', 'value': 'Aggregates'}, 'capitalCity': '', 'longitude': '', 'latitude': ''}]

# %%
print(data[0])
print(len(data))

#  1 --> Meta data
# 2 --> Actual data
# Out:
# {'page': 1, 'pages': 1, 'per_page': '300', 'total': 296}
# 2

# %%
countries = data[1]
countries = pd.DataFrame(countries)

# %%
countries
# Out:
#       id iso2Code                                               name  \
# 0    ABW       AW                                              Aruba
# 1    AFE       ZH                        Africa Eastern and Southern
# 2    AFG       AF                                        Afghanistan
# 3    AFR       A9                                             Africa
# 4    AFW       ZI                         Africa Western and Central
# ..   ...      ...                                                ...
# 291  XZN       A5  Sub-Saharan Africa excluding South Africa and ...
# 292  YEM       YE                                        Yemen, Rep.
# 293  ZAF       ZA                                       South Africa
# 294  ZMB       ZM                                             Zambia
# 295  ZWE       ZW                                           Zimbabwe
#
#                                                 region  \
# 0    {'id': 'LCN', 'iso2code': 'ZJ', 'value': 'Lati...
# 1    {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggre...
# 2    {'id': 'MEA', 'iso2code': 'ZQ', 'value': 'Midd...
# 3    {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggre...
# 4    {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggre...
# ..                                                 ...
# 291  {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggre...
# 292  {'id': 'MEA', 'iso2code': 'ZQ', 'value': 'Midd...
# 293  {'id': 'SSF', 'iso2code': 'ZG', 'value': 'Sub-...
# 294  {'id': 'SSF', 'iso2code': 'ZG', 'value': 'Sub-...
# 295  {'id': 'SSF', 'iso2code': 'ZG', 'value': 'Sub-...
#
#                                            adminregion  \
# 0              {'id': '', 'iso2code': '', 'value': ''}
# 1              {'id': '', 'iso2code': '', 'value': ''}
# 2    {'id': 'MNA', 'iso2code': 'XQ', 'value': 'Midd...
# 3              {'id': '', 'iso2code': '', 'value': ''}
# 4              {'id': '', 'iso2code': '', 'value': ''}
# ..                                                 ...
# 291            {'id': '', 'iso2code': '', 'value': ''}
# 292  {'id': 'MNA', 'iso2code': 'XQ', 'value': 'Midd...
# 293  {'id': 'SSA', 'iso2code': 'ZF', 'value': 'Sub-...
# 294  {'id': 'SSA', 'iso2code': 'ZF', 'value': 'Sub-...
# 295  {'id': 'SSA', 'iso2code': 'ZF', 'value': 'Sub-...
#
#                                            incomeLevel  \
# 0    {'id': 'HIC', 'iso2code': 'XD', 'value': 'High...
# 1    {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggre...
# 2    {'id': 'LIC', 'iso2code': 'XM', 'value': 'Low ...
# 3    {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggre...
# 4    {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggre...
# ..                                                 ...
# 291  {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggre...
# 292  {'id': 'LIC', 'iso2code': 'XM', 'value': 'Low ...
# 293  {'id': 'UMC', 'iso2code': 'XT', 'value': 'Uppe...
# 294  {'id': 'LMC', 'iso2code': 'XN', 'value': 'Lowe...
# 295  {'id': 'LMC', 'iso2code': 'XN', 'value': 'Lowe...
#
#                                            lendingType capitalCity longitude  \
# 0    {'id': 'LNX', 'iso2code': 'XX', 'value': 'Not ...  Oranjestad  -70.0167
# 1    {'id': '', 'iso2code': '', 'value': 'Aggregates'}
# 2      {'id': 'IDX', 'iso2code': 'XI', 'value': 'IDA'}       Kabul   69.1761
# 3    {'id': '', 'iso2code': '', 'value': 'Aggregates'}
# 4    {'id': '', 'iso2code': '', 'value': 'Aggregates'}
# ..                                                 ...         ...       ...
# 291  {'id': '', 'iso2code': '', 'value': 'Aggregates'}
# 292    {'id': 'IDX', 'iso2code': 'XI', 'value': 'IDA'}      Sana'a   44.2075
# 293   {'id': 'IBD', 'iso2code': 'XF', 'value': 'IBRD'}    Pretoria   28.1871
# 294    {'id': 'IDX', 'iso2code': 'XI', 'value': 'IDA'}      Lusaka   28.2937
# 295  {'id': 'IDB', 'iso2code': 'XH', 'value': 'Blend'}      Harare   31.0672
#
#      latitude
# 0     12.5167
# 1
# 2     34.5228
# 3
# 4
# ..        ...
# 291
# 292    15.352
# 293   -25.746
# 294  -15.3982
# 295  -17.8312
#
# [296 rows x 10 columns]

# %%
countries["incomeLevel"][1]
# Out:
# {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'}

# %%
countries["region"] = countries["region"].apply(lambda x:x["value"])

# %%
countries["incomeLevel"] = countries["incomeLevel"].apply(lambda x:x["value"])

# %%
countries["lendingType"] = countries["lendingType"].apply(lambda x:x["value"])

# %%
countries.drop(columns=["adminregion" , "capitalCity" , "lendingType"], inplace = True)

# %%
countries
# Out:
#       id iso2Code                                               name  \
# 0    ABW       AW                                              Aruba
# 1    AFE       ZH                        Africa Eastern and Southern
# 2    AFG       AF                                        Afghanistan
# 3    AFR       A9                                             Africa
# 4    AFW       ZI                         Africa Western and Central
# ..   ...      ...                                                ...
# 291  XZN       A5  Sub-Saharan Africa excluding South Africa and ...
# 292  YEM       YE                                        Yemen, Rep.
# 293  ZAF       ZA                                       South Africa
# 294  ZMB       ZM                                             Zambia
# 295  ZWE       ZW                                           Zimbabwe
#
#                                                 region          incomeLevel  \
# 0                           Latin America & Caribbean           High income
# 1                                           Aggregates           Aggregates
# 2    Middle East, North Africa, Afghanistan & Pakistan           Low income
# 3                                           Aggregates           Aggregates
# 4                                           Aggregates           Aggregates
# ..                                                 ...                  ...
# 291                                         Aggregates           Aggregates
# 292  Middle East, North Africa, Afghanistan & Pakistan           Low income
# 293                                Sub-Saharan Africa   Upper middle income
# 294                                Sub-Saharan Africa   Lower middle income
# 295                                Sub-Saharan Africa   Lower middle income
#
#     longitude  latitude
# 0    -70.0167   12.5167
# 1
# 2     69.1761   34.5228
# 3
# 4
# ..        ...       ...
# 291
# 292   44.2075    15.352
# 293   28.1871   -25.746
# 294   28.2937  -15.3982
# 295   31.0672  -17.8312
#
# [296 rows x 7 columns]

# %%
countries.rename(columns ={"iso2Code":"country_id"}, inplace=True)

# %%
countries[countries["region"] == "Aggregates"]
# Out:
#       id country_id                                               name  \
# 1    AFE         ZH                        Africa Eastern and Southern
# 3    AFR         A9                                             Africa
# 4    AFW         ZI                         Africa Western and Central
# 8    ARB         1A                                         Arab World
# 18   BEA         B4          East Asia & Pacific (IBRD-only countries)
# ..   ...        ...                                                ...
# 269  TSA         T5                            South Asia (IDA & IBRD)
# 270  TSS         T6          Sub-Saharan Africa (IDA & IBRD countries)
# 278  UMC         XT                                Upper middle income
# 288  WLD         1W                                              World
# 291  XZN         A5  Sub-Saharan Africa excluding South Africa and ...
#
#          region incomeLevel longitude latitude
# 1    Aggregates  Aggregates
# 3    Aggregates  Aggregates
# 4    Aggregates  Aggregates
# 8    Aggregates  Aggregates
# 18   Aggregates  Aggregates
# ..          ...         ...       ...      ...
# 269  Aggregates  Aggregates
# 270  Aggregates  Aggregates
# 278  Aggregates  Aggregates
# 288  Aggregates  Aggregates
# 291  Aggregates  Aggregates
#
# [79 rows x 7 columns]

# %%
# code for indicator
base_url = "https://api.worldbank.org/v2/indicator?format=json&per_page=50"
response = requests.get(base_url)
response.status_code

# %%
data = response.json()

# %%
data[0]
# Out:
# {'page': 1, 'pages': 587, 'per_page': '50', 'total': 29323}

# %%
pd.DataFrame(data[1])

# %%
all_dfs = []
for i in range(1 , 588):
    url = f"https://api.worldbank.org/v2/indicator?format=json&per_page=500&page={i}"
    response = requests.get(url)
    
    if response.status_code == 200:
      data = response.json()

      if len(data)<2 or data[1] is None:
          print(f"No data at page{i}")
          continue

      indicators = data[1]
      df = pd.DataFrame([{"id":item["id"] ,
                          "name":item["name"]} for item in indicators])
      all_dfs.append(df)
      print(f"Page{i}: {len(df)} indicators collector")
    else:
        print(f"Failed to fetch page {i} , status code {response.status_code}")
# Out:
# Page1: 500 indicators collector
# Page2: 500 indicators collector
# Page3: 500 indicators collector
# Page4: 500 indicators collector
# Page5: 500 indicators collector
# Page6: 500 indicators collector
# Page7: 500 indicators collector
# Page8: 500 indicators collector
# Page9: 500 indicators collector
# Page10: 500 indicators collector
# Page11: 500 indicators collector
# Page12: 500 indicators collector
# Page13: 500 indicators collector
# Page14: 500 indicators collector
# Page15: 500 indicators collector
# Page16: 500 indicators collector
# Page17: 500 indicators collector
# Page18: 500 indicators collector
# Page19: 500 indicators collector
# Page20: 500 indicators collector
# Page21: 500 indicators collector
# Page22: 500 indicators collector
# Page23: 500 indicators collector
# Page24: 500 indicators collector
# Page25: 500 indicators collector
# Page26: 500 indicators collector
# Page27: 500 indicators collector
# Page28: 500 indicators collector
# Page29: 500 indicators collector
# Page30: 500 indicators collector
# Page31: 500 indicators collector
# Page32: 500 indicators collector
# Page33: 500 indicators collector
# Page34: 500 indicators collector
# Page35: 500 indicators collector
# Page36: 500 indicators collector
# Page37: 500 indicators collector
# Page38: 500 indicators collector
# Page39: 500 indicators collector
# Page40: 500 indicators collector
# Page41: 500 indicators collector
# Page42: 500 indicators collector
# Page43: 500 indicators collector
# Page44: 500 indicators collector
# Page45: 500 indicators collector
# Page46: 500 indicators collector
# Page47: 500 indicators collector
# Page48: 500 indicators collector
# Page49: 500 indicators collector
# Page50: 500 indicators collector
# Page51: 500 indicators collector
# Page52: 500 indicators collector
# Page53: 500 indicators collector
# Page54: 500 indicators collector
# Page55: 500 indicators collector
# Page56: 500 indicators collector
# Page57: 500 indicators collector
# Page58: 500 indicators collector
# Page59: 323 indicators collector
# Page60: 0 indicators collector
# Page61: 0 indicators collector
# Page62: 0 indicators collector
# Page63: 0 indicators collector
# Page64: 0 indicators collector
# Page65: 0 indicators collector
# Page66: 0 indicators collector
# Page67: 0 indicators collector
# Page68: 0 indicators collector
# Page69: 0 indicators collector
# Page70: 0 indicators collector
# Page71: 0 indicators collector
# Page72: 0 indicators collector
# Page73: 0 indicators collector
# Page74: 0 indicators collector
# Page75: 0 indicators collector
# Page76: 0 indicators collector
# Page77: 0 indicators collector
# Page78: 0 indicators collector
# Page79: 0 indicators collector
# Page80: 0 indicators collector
# Page81: 0 indicators collector
# Page82: 0 indicators collector
# Page83: 0 indicators collector
# Page84: 0 indicators collector
# Page85: 0 indicators collector
# Page86: 0 indicators collector
# Page87: 0 indicators collector
# Page88: 0 indicators collector
# Page89: 0 indicators collector
# Page90: 0 indicators collector
# Page91: 0 indicators collector
# Page92: 0 indicators collector
# Page93: 0 indicators collector
# Page94: 0 indicators collector
# Page95: 0 indicators collector
# Page96: 0 indicators collector
# Page97: 0 indicators collector
# Page98: 0 indicators collector
# Page99: 0 indicators collector
# Page100: 0 indicators collector
# Page101: 0 indicators collector
# Page102: 0 indicators collector
# Page103: 0 indicators collector
# Page104: 0 indicators collector
# Page105: 0 indicators collector
# Page106: 0 indicators collector
# Page107: 0 indicators collector
# Page108: 0 indicators collector
# Page109: 0 indicators collector
# Page110: 0 indicators collector
# Page111: 0 indicators collector
# Page112: 0 indicators collector
# Page113: 0 indicators collector
# Page114: 0 indicators collector
# Page115: 0 indicators collector
# Page116: 0 indicators collector
# Page117: 0 indicators collector
# Page118: 0 indicators collector
# Page119: 0 indicators collector
# Page120: 0 indicators collector
# Page121: 0 indicators collector
# Page122: 0 indicators collector
# Page123: 0 indicators collector
# Page124: 0 indicators collector
# Page125: 0 indicators collector
# Page126: 0 indicators collector
# Page127: 0 indicators collector
# Page128: 0 indicators collector
# Page129: 0 indicators collector
# Page130: 0 indicators collector
# Page131: 0 indicators collector
# Page132: 0 indicators collector
# Page133: 0 indicators collector
# Page134: 0 indicators collector
# Page135: 0 indicators collector
# Page136: 0 indicators collector
# Page137: 0 indicators collector
# Page138: 0 indicators collector
# Page139: 0 indicators collector
# Page140: 0 indicators collector
# Page141: 0 indicators collector
# Page142: 0 indicators collector
# Page143: 0 indicators collector
# Page144: 0 indicators collector
# Page145: 0 indicators collector
# Page146: 0 indicators collector
# Page147: 0 indicators collector
# Page148: 0 indicators collector
# Page149: 0 indicators collector
# Page150: 0 indicators collector
# Page151: 0 indicators collector
# Page152: 0 indicators collector
# Page153: 0 indicators collector
# Page154: 0 indicators collector
# Page155: 0 indicators collector
# Page156: 0 indicators collector
# Page157: 0 indicators collector
# Page158: 0 indicators collector
# Page159: 0 indicators collector
# Page160: 0 indicators collector
# Page161: 0 indicators collector
# Page162: 0 indicators collector
# Page163: 0 indicators collector
# Page164: 0 indicators collector
# Page165: 0 indicators collector
# Page166: 0 indicators collector
# Page167: 0 indicators collector
# Page168: 0 indicators collector
# Page169: 0 indicators collector
# Page170: 0 indicators collector
# Page171: 0 indicators collector
# Page172: 0 indicators collector
# Page173: 0 indicators collector
# Page174: 0 indicators collector
# Page175: 0 indicators collector
# Page176: 0 indicators collector
# Page177: 0 indicators collector
# Page178: 0 indicators collector
# Page179: 0 indicators collector
# Page180: 0 indicators collector
# Page181: 0 indicators collector
# Page182: 0 indicators collector
# Page183: 0 indicators collector
# Page184: 0 indicators collector
# Page185: 0 indicators collector
# Page186: 0 indicators collector
# Page187: 0 indicators collector
# Page188: 0 indicators collector
# Page189: 0 indicators collector
# Page190: 0 indicators collector
# Page191: 0 indicators collector
# Page192: 0 indicators collector
# Page193: 0 indicators collector
# Page194: 0 indicators collector
# Page195: 0 indicators collector
# Page196: 0 indicators collector
# Page197: 0 indicators collector
# Page198: 0 indicators collector
# Page199: 0 indicators collector
# Page200: 0 indicators collector
# Page201: 0 indicators collector
# Page202: 0 indicators collector
# Page203: 0 indicators collector
# Page204: 0 indicators collector
# Page205: 0 indicators collector
# Page206: 0 indicators collector
# Page207: 0 indicators collector
# Page208: 0 indicators collector
# Page209: 0 indicators collector
# Page210: 0 indicators collector
# Page211: 0 indicators collector
# Page212: 0 indicators collector
# Page213: 0 indicators collector
# Page214: 0 indicators collector
# Page215: 0 indicators collector
# Page216: 0 indicators collector
# Page217: 0 indicators collector
# Page218: 0 indicators collector
# Page219: 0 indicators collector
# Page220: 0 indicators collector
# Page221: 0 indicators collector
# Page222: 0 indicators collector
# Page223: 0 indicators collector
# Page224: 0 indicators collector
# Page225: 0 indicators collector
# Page226: 0 indicators collector
# Page227: 0 indicators collector
# Page228: 0 indicators collector
# Page229: 0 indicators collector
# Page230: 0 indicators collector
# Page231: 0 indicators collector
# Page232: 0 indicators collector
# Page233: 0 indicators collector
# Page234: 0 indicators collector
# Page235: 0 indicators collector
# Page236: 0 indicators collector
# Page237: 0 indicators collector
# Page238: 0 indicators collector
# Page239: 0 indicators collector
# Page240: 0 indicators collector
# Page241: 0 indicators collector
# Page242: 0 indicators collector
# Page243: 0 indicators collector
# Page244: 0 indicators collector
# Page245: 0 indicators collector
# Page246: 0 indicators collector
# Page247: 0 indicators collector
# Page248: 0 indicators collector
# Page249: 0 indicators collector
# Page250: 0 indicators collector
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\urllib3\connectionpool.py:488, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     487         new_e = _wrap_proxy_error(new_e, conn.proxy.scheme)
# --> 488     raise new_e
#     490 # conn.request() calls http.client.*.request, not the method in
#     491 # urllib3.request. It also calls makefile (recv) on the socket.
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\urllib3\connectionpool.py:464, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     463 try:
# --> 464     self._validate_conn(conn)
#     465 except (SocketTimeout, BaseSSLError) as e:
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\urllib3\connectionpool.py:1093, in HTTPSConnectionPool._validate_conn(self, conn)
#    1092 if conn.is_closed:
# -> 1093     conn.connect()
#    1095 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\urllib3\connection.py:796, in HTTPSConnection.connect(self)
#     794 server_hostname_rm_dot = server_hostname.rstrip(".")
# --> 796 sock_and_verified = _ssl_wrap_socket_and_match_hostname(
#     797     sock=sock,
#     798     cert_reqs=self.cert_reqs,
#     799     ssl_version=self.ssl_version,
#     800     ssl_minimum_version=self.ssl_minimum_version,
#     801     ssl_maximum_version=self.ssl_maximum_version,
#     802     ca_certs=self.ca_certs,
#     803     ca_cert_dir=self.ca_cert_dir,
#     804     ca_cert_data=self.ca_cert_data,
#     805     cert_file=self.cert_file,
#     806     key_file=self.key_file,
#     807     key_password=self.key_password,
#     808     server_hostname=server_hostname_rm_dot,
#     809     ssl_context=self.ssl_context,
#     810     tls_in_tls=tls_in_tls,
#     811     assert_hostname=self.assert_hostname,
#     812     assert_fingerprint=self.assert_fingerprint,
#     813 )
#     814 self.sock = sock_and_verified.socket
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\urllib3\connection.py:975, in _ssl_wrap_socket_and_match_hostname(sock, cert_reqs, ssl_version, ssl_minimum_version, ssl_maximum_version, cert_file, key_file, key_password, ca_certs, ca_cert_dir, ca_cert_data, assert_hostname, assert_fingerprint, server_hostname, ssl_context, tls_in_tls)
#     973         server_hostname = normalized
# --> 975 ssl_sock = ssl_wrap_socket(
#     976     sock=sock,
#     977     keyfile=key_file,
#     978     certfile=cert_file,
#     979     key_password=key_password,
#     980     ca_certs=ca_certs,
#     981     ca_cert_dir=ca_cert_dir,
#     982     ca_cert_data=ca_cert_data,
#     983     server_hostname=server_hostname,
#     984     ssl_context=context,
#     985     tls_in_tls=tls_in_tls,
#     986 )
#     988 try:
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\urllib3\util\ssl_.py:483, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     481 context.set_alpn_protocols(ALPN_PROTOCOLS)
# --> 483 ssl_sock = _ssl_wrap_socket_impl(sock, context, tls_in_tls, server_hostname)
#     484 return ssl_sock
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\urllib3\util\ssl_.py:527, in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     525     return SSLTransport(sock, ssl_context, server_hostname)
# --> 527 return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\ssl.py:455, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     449 def wrap_socket(self, sock, server_side=False,
#     450                 do_handshake_on_connect=True,
#     451                 suppress_ragged_eofs=True,
#     452                 server_hostname=None, session=None):
#     453     # SSLSocket class handles server_hostname encoding before it calls
#     454     # ctx._wrap_socket()
# --> 455     return self.sslsocket_class._create(
#     456         sock=sock,
#     457         server_side=server_side,
#     458         do_handshake_on_connect=do_handshake_on_connect,
#     459         suppress_ragged_eofs=suppress_ragged_eofs,
#     460         server_hostname=server_hostname,
#     461         context=self,
#     462         session=session
#     463     )
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\ssl.py:1076, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1075                 raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1076             self.do_handshake()
#    1077 except:
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\ssl.py:1372, in SSLSocket.do_handshake(self, block)
#    1371         self.settimeout(None)
# -> 1372     self._sslobj.do_handshake()
#    1373 finally:
#
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\requests\adapters.py:644, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     643 try:
# --> 644     resp = conn.urlopen(
#     645         method=request.method,
#     646         url=url,
#     647         body=request.body,
#     648         headers=request.headers,
#     649         redirect=False,
#     650         assert_same_host=False,
#     651         preload_content=False,
#     652         decode_content=False,
#     653         retries=self.max_retries,
#     654         timeout=timeout,
#     655         chunked=chunked,
#     656     )
#     658 except (ProtocolError, OSError) as err:
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\urllib3\connectionpool.py:841, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     839     new_e = ProtocolError("Connection aborted.", new_e)
# --> 841 retries = retries.increment(
#     842     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     843 )
#     844 retries.sleep()
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\urllib3\util\retry.py:474, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     473 if read is False or method is None or not self._is_method_retryable(method):
# --> 474     raise reraise(type(error), error, _stacktrace)
#     475 elif read is not None:
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\urllib3\util\util.py:38, in reraise(tp, value, tb)
#      37 if value.__traceback__ is not tb:
# ---> 38     raise value.with_traceback(tb)
#      39 raise value
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\urllib3\connectionpool.py:488, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     487         new_e = _wrap_proxy_error(new_e, conn.proxy.scheme)
# --> 488     raise new_e
#     490 # conn.request() calls http.client.*.request, not the method in
#     491 # urllib3.request. It also calls makefile (recv) on the socket.
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\urllib3\connectionpool.py:464, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     463 try:
# --> 464     self._validate_conn(conn)
#     465 except (SocketTimeout, BaseSSLError) as e:
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\urllib3\connectionpool.py:1093, in HTTPSConnectionPool._validate_conn(self, conn)
#    1092 if conn.is_closed:
# -> 1093     conn.connect()
#    1095 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\urllib3\connection.py:796, in HTTPSConnection.connect(self)
#     794 server_hostname_rm_dot = server_hostname.rstrip(".")
# --> 796 sock_and_verified = _ssl_wrap_socket_and_match_hostname(
#     797     sock=sock,
#     798     cert_reqs=self.cert_reqs,
#     799     ssl_version=self.ssl_version,
#     800     ssl_minimum_version=self.ssl_minimum_version,
#     801     ssl_maximum_version=self.ssl_maximum_version,
#     802     ca_certs=self.ca_certs,
#     803     ca_cert_dir=self.ca_cert_dir,
#     804     ca_cert_data=self.ca_cert_data,
#     805     cert_file=self.cert_file,
#     806     key_file=self.key_file,
#     807     key_password=self.key_password,
#     808     server_hostname=server_hostname_rm_dot,
#     809     ssl_context=self.ssl_context,
#     810     tls_in_tls=tls_in_tls,
#     811     assert_hostname=self.assert_hostname,
#     812     assert_fingerprint=self.assert_fingerprint,
#     813 )
#     814 self.sock = sock_and_verified.socket
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\urllib3\connection.py:975, in _ssl_wrap_socket_and_match_hostname(sock, cert_reqs, ssl_version, ssl_minimum_version, ssl_maximum_version, cert_file, key_file, key_password, ca_certs, ca_cert_dir, ca_cert_data, assert_hostname, assert_fingerprint, server_hostname, ssl_context, tls_in_tls)
#     973         server_hostname = normalized
# --> 975 ssl_sock = ssl_wrap_socket(
#     976     sock=sock,
#     977     keyfile=key_file,
#     978     certfile=cert_file,
#     979     key_password=key_password,
#     980     ca_certs=ca_certs,
#     981     ca_cert_dir=ca_cert_dir,
#     982     ca_cert_data=ca_cert_data,
#     983     server_hostname=server_hostname,
#     984     ssl_context=context,
#     985     tls_in_tls=tls_in_tls,
#     986 )
#     988 try:
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\urllib3\util\ssl_.py:483, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     481 context.set_alpn_protocols(ALPN_PROTOCOLS)
# --> 483 ssl_sock = _ssl_wrap_socket_impl(sock, context, tls_in_tls, server_hostname)
#     484 return ssl_sock
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\urllib3\util\ssl_.py:527, in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     525     return SSLTransport(sock, ssl_context, server_hostname)
# --> 527 return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\ssl.py:455, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     449 def wrap_socket(self, sock, server_side=False,
#     450                 do_handshake_on_connect=True,
#     451                 suppress_ragged_eofs=True,
#     452                 server_hostname=None, session=None):
#     453     # SSLSocket class handles server_hostname encoding before it calls
#     454     # ctx._wrap_socket()
# --> 455     return self.sslsocket_class._create(
#     456         sock=sock,
#     457         server_side=server_side,
#     458         do_handshake_on_connect=do_handshake_on_connect,
#     459         suppress_ragged_eofs=suppress_ragged_eofs,
#     460         server_hostname=server_hostname,
#     461         context=self,
#     462         session=session
#     463     )
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\ssl.py:1076, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1075                 raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1076             self.do_handshake()
#    1077 except:
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\ssl.py:1372, in SSLSocket.do_handshake(self, block)
#    1371         self.settimeout(None)
# -> 1372     self._sslobj.do_handshake()
#    1373 finally:
#
# ProtocolError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[140], line 4
#       2 for i in range(1 , 588):
#       3     url = f"https://api.worldbank.org/v2/indicator?format=json&per_page=500&page={i}"
# ----> 4     response = requests.get(url)
#       6     if response.status_code == 200:
#       7       data = response.json()
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)     70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\requests\adapters.py:659, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     644     resp = conn.urlopen(
#     645         method=request.method,
#     646         url=url,
#    (...)    655         chunked=chunked,
#     656     )
#     658 except (ProtocolError, OSError) as err:
# --> 659     raise ConnectionError(err, request=request)
#     661 except MaxRetryError as e:
#     662     if isinstance(e.reason, ConnectTimeoutError):
#     663         # TODO: Remove this in 3.0.0: see #2811
#
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))

# %%
#data - 0 ,1
# metadata
# actual data

# %%
import requests
import pandas as pd

base_url = "https://api.worldbank.org/v2/indicator"
params = {
    "format": "json",
    "per_page": 500,
    "page": 1
}

response = requests.get(base_url, params=params)
data = response.json()

total_pages = data[0]["pages"]
print("Total pages:", total_pages)
# Out:
# Total pages: 59

# %%
all_dfs = []

for i in range(1, total_pages + 1):
    params["page"] = i
    response = requests.get(base_url, params=params)
    data = response.json()

    indicators = data[1]

    df = pd.DataFrame([
        {
            "id": item["id"],
            "name": item["name"]
        }
        for item in indicators
    ])

    all_dfs.append(df)
    print(f"Page {i}: {len(df)} indicators collected")
# Out:
# Page 1: 500 indicators collected
# Page 2: 500 indicators collected
# Page 3: 500 indicators collected
# Page 4: 500 indicators collected
# Page 5: 500 indicators collected
# Page 6: 500 indicators collected
# Page 7: 500 indicators collected
# Page 8: 500 indicators collected
# Page 9: 500 indicators collected
# Page 10: 500 indicators collected
# Page 11: 500 indicators collected
# Page 12: 500 indicators collected
# Page 13: 500 indicators collected
# Page 14: 500 indicators collected
# Page 15: 500 indicators collected
# Page 16: 500 indicators collected
# Page 17: 500 indicators collected
# Page 18: 500 indicators collected
# Page 19: 500 indicators collected
# Page 20: 500 indicators collected
# Page 21: 500 indicators collected
# Page 22: 500 indicators collected
# Page 23: 500 indicators collected
# Page 24: 500 indicators collected
# Page 25: 500 indicators collected
# Page 26: 500 indicators collected
# Page 27: 500 indicators collected
# Page 28: 500 indicators collected
# Page 29: 500 indicators collected
# Page 30: 500 indicators collected
# Page 31: 500 indicators collected
# Page 32: 500 indicators collected
# Page 33: 500 indicators collected
# Page 34: 500 indicators collected
# Page 35: 500 indicators collected
# Page 36: 500 indicators collected
# Page 37: 500 indicators collected
# Page 38: 500 indicators collected
# Page 39: 500 indicators collected
# Page 40: 500 indicators collected
# Page 41: 500 indicators collected
# Page 42: 500 indicators collected
# Page 43: 500 indicators collected
# Page 44: 500 indicators collected
# Page 45: 500 indicators collected
# Page 46: 500 indicators collected
# Page 47: 500 indicators collected
# Page 48: 500 indicators collected
# Page 49: 500 indicators collected
# Page 50: 500 indicators collected
# Page 51: 500 indicators collected
# Page 52: 500 indicators collected
# Page 53: 500 indicators collected
# Page 54: 500 indicators collected
# Page 55: 500 indicators collected
# Page 56: 500 indicators collected
# Page 57: 500 indicators collected
# Page 58: 500 indicators collected
# Page 59: 323 indicators collected

# %%
final_df = pd.concat(all_dfs, ignore_index=True)
print(final_df.shape)
# Out:
# (29323, 2)

# %%
final_df.to_csv("final_df.csv")

# %%
#extrect value from various indictors under the domain for each country

# %%
indicatore_groups = {
    "economic_activity_growth":["NY.GDP.MKTP.Kd.ZG","NY.GDP.PCAP.CD"],
    "labour_market_indicators":["SL.UEM.TOTL.ZS","SL.UEM.1524.ZS","SL.TLF.TOTL.IN"],
    "trade_globalization":["NE.EXP.GNFS.CD" , "NE.TLF.TOTL.IN"],
    "poverty_inequality":["SI.POV.NAHC", "SI.POV.GINI"],
    "environmental_indicators":["EG.FEC.RNEW.ZS" , "AG.LND.FRST.ZS"],
    "health_indicators" :["SP.DYN.LE00.IN" , "SP.DYN.IMRT.IN", "SH.H2O.BASW.ZS" , "SH.XPD.CHEX..GD.ZS" , "SH.IMM.IDPT" , "SH.IMM.MEAS" , "SH.MMR.RISK.ZS" , 
                          "SH.DTH.COMM.ZS" , "SH.TBS.INCD", "SH.STA.BRTC.ZS" , "SH.STA.MART" , "SH.POP.6SUP.TO.ZS" , "SH.HIV.INCD.ZS"] , 
    "technology_indicators" : ["IT.NET.USER.ZS" , "IT.CEL.SETS.P2"]}

# %%
base_url= requests.get("https://api.worldbank.org/countries/all/indicators/{}?format=json&per_page= 1000&page={}")

# %%
import time
base_url = (
    "https://api.worldbank.org/v2/country/all/indicator/{}"
    "?format=json&per_page=1000&page={}&date=2016:2023"
)



category_dataframes = {}
for category,indicators in indicatore_groups.items():
    print(f"Fetch information for category : {category}")
    all_dfs_for_category = []

    for indicator_code in indicators:
        print(f"Fetching indicator: {indicator_code}")
        page=1

        while True:
            url = base_url.format(indicator_code , page)
            response = requests.get(url)
            if response.status_code!=200:
                print(f"No data for indicator{indicator_code}on page {page}")
            try:
                 data = response.json()
            except ValueError:
                 print(f"Invalid JSON for {indicator_code} at page {page}")
                 break
            if len(data) < 2 or data[1] is None:
               print(f"No records for {indicator_code} at page {page}")
               break


            total_pages = data[0]["pages"]
            record = data[1]

            df = pd.json_normalize(record)
            df = df[[
                "country.id","country.value","indicator.id","indicator.value" , "date" , "value"]].rename(columns={"country.id":"country_id",
                                                                                                                   "country.value":"country_value",
                                                                                                                   "indicator.id":"indicator_id",
                                                                                                                   "indicator.value":"indicator_name",
                                                                                                                  "date":"year"})
            df = df[df["year"].astype(int)>2015]
            all_dfs_for_category.append(df)

            if page>=total_pages:
                break
            else:
                page += 1
                time.sleep(0.3)


        if all_dfs_for_category:
            combine_df = pd.concat(all_dfs_for_category , ignore_index = True)
            category_dataframes[category]=combine_df
            print(f"Total row collectes for  {category} :{len(combine_df)}")
        else:
            print(f"No data collected for {category}")

print("Data Fecthing Completed")
# Out:
# Fetch information for category : economic_activity_growth
# Fetching indicator: NY.GDP.MKTP.Kd.ZG
# Total row collectes for  economic_activity_growth :2128
# Fetching indicator: NY.GDP.PCAP.CD
# Total row collectes for  economic_activity_growth :4256
# Fetch information for category : labour_market_indicators
# Fetching indicator: SL.UEM.TOTL.ZS
# Total row collectes for  labour_market_indicators :2128
# Fetching indicator: SL.UEM.1524.ZS
# Total row collectes for  labour_market_indicators :4256
# Fetching indicator: SL.TLF.TOTL.IN
# Total row collectes for  labour_market_indicators :6384
# Fetch information for category : trade_globalization
# Fetching indicator: NE.EXP.GNFS.CD
# Total row collectes for  trade_globalization :2128
# Fetching indicator: NE.TLF.TOTL.IN
# No records for NE.TLF.TOTL.IN at page 1
# Total row collectes for  trade_globalization :2128
# Fetch information for category : poverty_inequality
# Fetching indicator: SI.POV.NAHC
# Total row collectes for  poverty_inequality :2128
# Fetching indicator: SI.POV.GINI
# Total row collectes for  poverty_inequality :4256
# Fetch information for category : environmental_indicators
# Fetching indicator: EG.FEC.RNEW.ZS
# Total row collectes for  environmental_indicators :2128
# Fetching indicator: AG.LND.FRST.ZS
# Total row collectes for  environmental_indicators :4256
# Fetch information for category : health_indicators
# Fetching indicator: SP.DYN.LE00.IN
# Total row collectes for  health_indicators :2128
# Fetching indicator: SP.DYN.IMRT.IN
# Total row collectes for  health_indicators :4256
# Fetching indicator: SH.H2O.BASW.ZS
# Total row collectes for  health_indicators :6384
# Fetching indicator: SH.XPD.CHEX..GD.ZS
# No records for SH.XPD.CHEX..GD.ZS at page 1
# Total row collectes for  health_indicators :6384
# Fetching indicator: SH.IMM.IDPT
# Total row collectes for  health_indicators :8512
# Fetching indicator: SH.IMM.MEAS
# Total row collectes for  health_indicators :10640
# Fetching indicator: SH.MMR.RISK.ZS
# Total row collectes for  health_indicators :12768
# Fetching indicator: SH.DTH.COMM.ZS
# No data for indicatorSH.DTH.COMM.ZSon page 3
# Invalid JSON for SH.DTH.COMM.ZS at page 3
# Total row collectes for  health_indicators :14768
# Fetching indicator: SH.TBS.INCD
# Total row collectes for  health_indicators :16896
# Fetching indicator: SH.STA.BRTC.ZS
# No data for indicatorSH.STA.BRTC.ZSon page 3
# Invalid JSON for SH.STA.BRTC.ZS at page 3
# Total row collectes for  health_indicators :18896
# Fetching indicator: SH.STA.MART
# No records for SH.STA.MART at page 1
# Total row collectes for  health_indicators :18896
# Fetching indicator: SH.POP.6SUP.TO.ZS
# No records for SH.POP.6SUP.TO.ZS at page 1
# Total row collectes for  health_indicators :18896
# Fetching indicator: SH.HIV.INCD.ZS
# Total row collectes for  health_indicators :21024
# Fetch information for category : technology_indicators
# Fetching indicator: IT.NET.USER.ZS
# Total row collectes for  technology_indicators :2128
# Fetching indicator: IT.CEL.SETS.P2
# ---------------------------------------------------------------------------
# ConnectionAbortedError                    Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\urllib3\connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\urllib3\connection.py:571, in HTTPConnection.getresponse(self)
#     570 # Get the response from http.client.HTTPConnection
# --> 571 httplib_response = super().getresponse()
#     573 try:
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\http\client.py:1450, in HTTPConnection.getresponse(self)
#    1449 try:
# -> 1450     response.begin()
#    1451 except ConnectionError:
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\http\client.py:336, in HTTPResponse.begin(self)
#     335 while True:
# --> 336     version, status, reason = self._read_status()
#     337     if status != CONTINUE:
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\http\client.py:297, in HTTPResponse._read_status(self)
#     296 def _read_status(self):
# --> 297     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     298     if len(line) > _MAXLINE:
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\socket.py:725, in SocketIO.readinto(self, b)
#     724 try:
# --> 725     return self._sock.recv_into(b)
#     726 except timeout:
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\ssl.py:1304, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1301         raise ValueError(
#    1302           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1303           self.__class__)
# -> 1304     return self.read(nbytes, buffer)
#    1305 else:
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\ssl.py:1138, in SSLSocket.read(self, len, buffer)
#    1137 if buffer is not None:
# -> 1138     return self._sslobj.read(len, buffer)
#    1139 else:
#
# ConnectionAbortedError: [WinError 10053] An established connection was aborted by the software in your host machine
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\requests\adapters.py:644, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     643 try:
# --> 644     resp = conn.urlopen(
#     645         method=request.method,
#     646         url=url,
#     647         body=request.body,
#     648         headers=request.headers,
#     649         redirect=False,
#     650         assert_same_host=False,
#     651         preload_content=False,
#     652         decode_content=False,
#     653         retries=self.max_retries,
#     654         timeout=timeout,
#     655         chunked=chunked,
#     656     )
#     658 except (ProtocolError, OSError) as err:
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\urllib3\connectionpool.py:841, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     839     new_e = ProtocolError("Connection aborted.", new_e)
# --> 841 retries = retries.increment(
#     842     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     843 )
#     844 retries.sleep()
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\urllib3\util\retry.py:474, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     473 if read is False or method is None or not self._is_method_retryable(method):
# --> 474     raise reraise(type(error), error, _stacktrace)
#     475 elif read is not None:
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\urllib3\util\util.py:38, in reraise(tp, value, tb)
#      37 if value.__traceback__ is not tb:
# ---> 38     raise value.with_traceback(tb)
#      39 raise value
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\urllib3\connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\urllib3\connection.py:571, in HTTPConnection.getresponse(self)
#     570 # Get the response from http.client.HTTPConnection
# --> 571 httplib_response = super().getresponse()
#     573 try:
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\http\client.py:1450, in HTTPConnection.getresponse(self)
#    1449 try:
# -> 1450     response.begin()
#    1451 except ConnectionError:
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\http\client.py:336, in HTTPResponse.begin(self)
#     335 while True:
# --> 336     version, status, reason = self._read_status()
#     337     if status != CONTINUE:
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\http\client.py:297, in HTTPResponse._read_status(self)
#     296 def _read_status(self):
# --> 297     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     298     if len(line) > _MAXLINE:
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\socket.py:725, in SocketIO.readinto(self, b)
#     724 try:
# --> 725     return self._sock.recv_into(b)
#     726 except timeout:
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\ssl.py:1304, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1301         raise ValueError(
#    1302           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1303           self.__class__)
# -> 1304     return self.read(nbytes, buffer)
#    1305 else:
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\ssl.py:1138, in SSLSocket.read(self, len, buffer)
#    1137 if buffer is not None:
# -> 1138     return self._sslobj.read(len, buffer)
#    1139 else:
#
# ProtocolError: ('Connection aborted.', ConnectionAbortedError(10053, 'An established connection was aborted by the software in your host machine', None, 10053, None))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[12], line 20
#      18 while True:
#      19     url = base_url.format(indicator_code , page)
# ---> 20     response = requests.get(url)
#      21     if response.status_code!=200:
#      22         print(f"No data for indicator{indicator_code}on page {page}")
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)     70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\requests\adapters.py:659, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     644     resp = conn.urlopen(
#     645         method=request.method,
#     646         url=url,
#    (...)    655         chunked=chunked,
#     656     )
#     658 except (ProtocolError, OSError) as err:
# --> 659     raise ConnectionError(err, request=request)
#     661 except MaxRetryError as e:
#     662     if isinstance(e.reason, ConnectTimeoutError):
#     663         # TODO: Remove this in 3.0.0: see #2811
#
# ConnectionError: ('Connection aborted.', ConnectionAbortedError(10053, 'An established connection was aborted by the software in your host machine', None, 10053, None))

# %%
response = requests.get(base_url)

# %%
response.json()[0]
# Out:
# {'page': 1,
#  'pages': 346,
#  'per_page': 50,
#  'total': 17290,
#  'sourceid': '2',
#  'lastupdated': '2025-12-19'}

# %%
economic_activity= category_dataframes.get("economic_activity_growth" ,pd.DataFrame())
labour_market_jobs = category_dataframes.get("labour_market_indicators" ,pd.DataFrame())
trade_globalization= category_dataframes.get("trade_globalization" ,pd.DataFrame())
poverty_inequality = category_dataframes.get("poverty_inequality" ,pd.DataFrame())
environmental_indicators = category_dataframes.get("environmental_indicators" ,pd.DataFrame())
health_indicators= category_dataframes.get("health_indicators" ,pd.DataFrame())
technology_indicator = category_dataframes.get("technology_indicators" ,pd.DataFrame())

# %%
economic = pd.merge(economic_activity , countries , on ="country_id" , how="inner")
labour_market = pd.merge(labour_market_jobs , countries , on ="country_id" , how="inner")
trade = pd.merge(trade_globalization , countries , on ="country_id" , how="inner")
poverty = pd.merge(poverty_inequality , countries , on ="country_id" , how="inner")
environment = pd.merge(environmental_indicators , countries , on ="country_id" , how="inner")
health =pd.merge(health_indicators, countries , on ="country_id" , how="inner")
technology =pd.merge(technology_indicator , countries , on ="country_id" , how="inner")

# %%
economic.drop(columns=["indicator_id" , "name" , "id"],inplace=True)
labour_market.drop(columns=["indicator_id" , "name" , "id"],inplace=True)
trade.drop(columns=["indicator_id" , "name" , "id"],inplace=True)
poverty.drop(columns=["indicator_id" , "name" , "id"],inplace=True)
environment.drop(columns=["indicator_id" , "name" , "id"],inplace=True)
health.drop(columns=["indicator_id" , "name" , "id"],inplace=True)
technology.drop(columns=["indicator_id" , "name" , "id"],inplace=True)

# %%
health
# Out:
#       country_id                country_value  \
# 0             ZH  Africa Eastern and Southern
# 1             ZH  Africa Eastern and Southern
# 2             ZH  Africa Eastern and Southern
# 3             ZH  Africa Eastern and Southern
# 4             ZH  Africa Eastern and Southern
# ...          ...                          ...
# 21019         ZW                     Zimbabwe
# 21020         ZW                     Zimbabwe
# 21021         ZW                     Zimbabwe
# 21022         ZW                     Zimbabwe
# 21023         ZW                     Zimbabwe
#
#                                           indicator_name  year      value  \
# 0                Life expectancy at birth, total (years)  2023  65.146154
# 1                Life expectancy at birth, total (years)  2022  64.487020
# 2                Life expectancy at birth, total (years)  2021  62.979999
# 3                Life expectancy at birth, total (years)  2020  63.766484
# 4                Life expectancy at birth, total (years)  2019  63.857261
# ...                                                  ...   ...        ...
# 21019  Incidence of HIV, ages 15-49 (per 1,000 uninfe...  2020   1.900000
# 21020  Incidence of HIV, ages 15-49 (per 1,000 uninfe...  2019   2.300000
# 21021  Incidence of HIV, ages 15-49 (per 1,000 uninfe...  2018   2.700000
# 21022  Incidence of HIV, ages 15-49 (per 1,000 uninfe...  2017   3.600000
# 21023  Incidence of HIV, ages 15-49 (per 1,000 uninfe...  2016   4.700000
#
#                     region          incomeLevel longitude  latitude
# 0               Aggregates           Aggregates
# 1               Aggregates           Aggregates
# 2               Aggregates           Aggregates
# 3               Aggregates           Aggregates
# 4               Aggregates           Aggregates
# ...                    ...                  ...       ...       ...
# 21019  Sub-Saharan Africa   Lower middle income   31.0672  -17.8312
# 21020  Sub-Saharan Africa   Lower middle income   31.0672  -17.8312
# 21021  Sub-Saharan Africa   Lower middle income   31.0672  -17.8312
# 21022  Sub-Saharan Africa   Lower middle income   31.0672  -17.8312
# 21023  Sub-Saharan Africa   Lower middle income   31.0672  -17.8312
#
# [21024 rows x 9 columns]

# %%
df_wide = health.pivot_table(index=["country_value","year"],
                             columns="indicator_name",
                             values="value"
                            )

# %%
economic.to_csv("economic.csv")
labour_market.to_csv("labour_market.csv")
trade.to_csv("trade.csv")
poverty.to_csv("poverty.csv")
environment.to_csv("environment.csv")
health.to_csv("health.csv")
technology.to_csv("technology.csv")

# %%
df_wide = health.pivot_table(index=["country_value","year"],
                             columns="indicator_name",
                             values="value"
                            )
corr = df_wide.corr()
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize =(20,20), facecolor = "none")
ax= sns.heatmap(
    corr,
    annot = True,
    cmap= "coolwarm",
    cbar_kws= {"label":"Correltion"},
    annot_kws = {"fontsize":14, "fontweight":"bold"}
)

plt.title("Reletionship between various health indicatores")
ax.tick_params(axis="x",labelsize = 14)
ax.tick_params(axis="x",labelsize = 14)
plt.show()

# %%
df_pivot = health.pivot(index=["country_value","year"],
                             columns="indicator_name",
                             values="value"
                            ).reset_index()
plt.figure(figsize=(12,8),facecolor="none")

ax=sns.regplot(data=df_pivot,
               x="Cause of death, by communicable diseases and maternal, prenatal and nutrition conditions (% of total)",
               y="Life expectancy at birth, total (years)",
               scatter_kws={"alpha":0.5,"s":40},
               line_kws = {"color":"red","lw":2}
              )

plt.title("Relationship between Expenditure and life Expectancy")
plt.xlabel("Current health expenditure(5 OF GDP)")
plt.ylabel("Life Expectancy at birth")
plt.grid(True)
plt.show()

# %%
df_pivot
# Out:
# indicator_name country_value  year  \
# 0                Afghanistan  2016
# 1                Afghanistan  2017
# 2                Afghanistan  2018
# 3                Afghanistan  2019
# 4                Afghanistan  2020
# ...                      ...   ...
# 2123                Zimbabwe  2019
# 2124                Zimbabwe  2020
# 2125                Zimbabwe  2021
# 2126                Zimbabwe  2022
# 2127                Zimbabwe  2023
#
# indicator_name  Births attended by skilled health staff (% of total)  \
# 0                                                             NaN
# 1                                                            53.4
# 2                                                            58.8
# 3                                                             NaN
# 4                                                            61.8
# ...                                                           ...
# 2123                                                          NaN
# 2124                                                          NaN
# 2125                                                          NaN
# 2126                                                          NaN
# 2127                                                          NaN
#
# indicator_name  Cause of death, by communicable diseases and maternal, prenatal and nutrition conditions (% of total)  \
# 0                                                             NaN
# 1                                                             NaN
# 2                                                             NaN
# 3                                                       32.930451
# 4                                                             NaN
# ...                                                           ...
# 2123                                                          NaN
# 2124                                                          NaN
# 2125                                                          NaN
# 2126                                                          NaN
# 2127                                                          NaN
#
# indicator_name  Immunization, DPT (% of children ages 12-23 months)  \
# 0                                                            66.0
# 1                                                            64.0
# 2                                                            68.0
# 3                                                            65.0
# 4                                                            61.0
# ...                                                           ...
# 2123                                                         90.0
# 2124                                                         86.0
# 2125                                                         88.0
# 2126                                                         90.0
# 2127                                                         90.0
#
# indicator_name  Immunization, measles (% of children ages 12-23 months)  \
# 0                                                            64.0
# 1                                                            64.0
# 2                                                            66.0
# 3                                                            57.0
# 4                                                            57.0
# ...                                                           ...
# 2123                                                         85.0
# 2124                                                         85.0
# 2125                                                         88.0
# 2126                                                         90.0
# 2127                                                         90.0
#
# indicator_name  Incidence of HIV, ages 15-49 (per 1,000 uninfected population ages 15-49)  \
# 0                                                             0.1
# 1                                                             0.1
# 2                                                             0.1
# 3                                                             0.1
# 4                                                             0.1
# ...                                                           ...
# 2123                                                          2.3
# 2124                                                          1.9
# 2125                                                          2.2
# 2126                                                          1.6
# 2127                                                          1.5
#
# indicator_name  Incidence of tuberculosis (per 100,000 people)  \
# 0                                                        204.0
# 1                                                        209.0
# 2                                                        212.0
# 3                                                        213.0
# 4                                                        205.0
# ...                                                        ...
# 2123                                                     199.0
# 2124                                                     189.0
# 2125                                                     198.0
# 2126                                                     209.0
# 2127                                                     209.0
#
# indicator_name  Life expectancy at birth, total (years)  \
# 0                                                62.646
# 1                                                62.406
# 2                                                62.443
# 3                                                62.941
# 4                                                61.454
# ...                                                 ...
# 2123                                             61.060
# 2124                                             61.530
# 2125                                             60.135
# 2126                                             62.360
# 2127                                             62.775
#
# indicator_name  Lifetime risk of maternal death (%)  \
# 0                                          3.775891
# 1                                          3.469739
# 2                                          3.246425
# 3                                          3.042626
# 4                                          3.135944
# ...                                             ...
# 2123                                       1.438150
# 2124                                       1.407570
# 2125                                       1.632553
# 2126                                       1.346997
# 2127                                       1.288230
#
# indicator_name  Mortality rate, infant (per 1,000 live births)  \
# 0                                                         62.3
# 1                                                         60.4
# 2                                                         58.6
# 3                                                         56.9
# 4                                                         55.3
# ...                                                        ...
# 2123                                                      46.0
# 2124                                                      44.9
# 2125                                                      43.6
# 2126                                                      42.2
# 2127                                                      40.6
#
# indicator_name  People using at least basic drinking water services (% of population)
# 0                                                       62.822070
# 1                                                       65.142136
# 2                                                       67.475869
# 3                                                       69.822698
# 4                                                       72.182071
# ...                                                           ...
# 2123                                                    67.179593
# 2124                                                    67.166424
# 2125                                                    67.162605
# 2126                                                    67.168908
# 2127                                                    67.184919
#
# [2128 rows x 12 columns]
